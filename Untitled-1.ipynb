# %%
# Standard libraries
import os
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
from IPython.display import display

# Machine Learning
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from scipy.cluster import hierarchy as hc
from fastai.imports import *

# %%
data = pd.read_csv('etc/data/auto2.csv')
data.shape
# Out:
# (93, 23)

# %%
data.iloc[0,:]
# Out:
# maker                             Acura
#  type                             Small
#  CityMPG+                            25
#  HighwayMPG+                         31
#  Air_Bags_standard                    0
#  Drive_train_type                     1
#  Number_of_cylinders                  4
#  Engine_size                        1.8
#  Horsepower                         140
#  RPM                               6300
#  Engine_revolutions_per_mile       2890
#  manual_transmission_available        1
#  Fuel_tank_capacity                13.2
#  Passenger_capacity                   5
#  Length                             177
#  Wheelbase                          102
#  Width                               68
#  U-turn_space                        37
#  Rear_seat_room                    26.5
#  Luggage_capacity                    11
#  Weight-                           2705
#  domestic                             0
#  Class-                            15.9
# Name: 0, dtype: object

# %%
# One hot encode matchType
data1 = pd.get_dummies(data, columns=[' type'])

# Take a look at the encoding
matchType_encoding = data1.filter(regex=' type')
matchType_encoding
# Out:
#      type_Compact   type_Large   type_Midsize   type_Small   type_Sporty
# 0           False        False          False         True         False  \
# 1           False        False           True        False         False
# 2            True        False          False        False         False
# 3           False        False           True        False         False
# 4           False        False           True        False         False
# ..            ...          ...            ...          ...           ...
# 88          False        False          False        False         False
# 89           True        False          False        False         False
# 90          False        False          False        False          True
# 91           True        False          False        False         False
# 92          False        False           True        False         False
#
#      type_Van
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 88       True
# 89      False
# 90      False
# 91      False
# 92      False
#
# [93 rows x 6 columns]

# %%
# One hot encode matchType
data2 = pd.get_dummies(data1, columns=['maker'])

# %%
data2
# Out:
#      CityMPG+   HighwayMPG+   Air_Bags_standard   Drive_train_type
# 0          25            31                   0                  1  \
# 1          18            25                   2                  1
# 2          20            26                   1                  1
# 3          19            26                   2                  1
# 4          22            30                   1                  0
# ..        ...           ...                 ...                ...
# 88         17            21                   0                  1
# 89         21            30                   0                  1
# 90         18            25                   0                  1
# 91         21            28                   1                  0
# 92         20            28                   2                  1
#
#     Number_of_cylinders   Engine_size   Horsepower   RPM
# 0                     4           1.8          140  6300  \
# 1                     6           3.2          200  5500
# 2                     6           2.8          172  5500
# 3                     6           2.8          172  5500
# 4                     4           3.5          208  5700
# ..                  ...           ...          ...   ...
# 88                    5           2.5          109  4500
# 89                    4           2.0          134  5800
# 90                    6           2.8          178  5800
# 91                    4           2.3          114  5400
# 92                    5           2.4          168  6200
#
#      Engine_revolutions_per_mile   manual_transmission_available  ...
# 0                           2890                               1  ...  \
# 1                           2335                               1  ...
# 2                           2280                               1  ...
# 3                           2535                               1  ...
# 4                           2545                               1  ...
# ..                           ...                             ...  ...
# 88                          2915                               1  ...
# 89                          2685                               1  ...
# 90                          2385                               1  ...
# 91                          2215                               1  ...
# 92                          2310                               1  ...
#
#     maker_Oldsmobile  maker_Plymouth  maker_Pontiac  maker_Saab  maker_Saturn
# 0              False           False          False       False         False  \
# 1              False           False          False       False         False
# 2              False           False          False       False         False
# 3              False           False          False       False         False
# 4              False           False          False       False         False
# ..               ...             ...            ...         ...           ...
# 88             False           False          False       False         False
# 89             False           False          False       False         False
# 90             False           False          False       False         False
# 91             False           False          False       False         False
# 92             False           False          False       False         False
#
#     maker_Subaru maker_Suzuki maker_Toyota  maker_Volkswagen  maker_Volvo
# 0          False        False        False             False        False
# 1          False        False        False             False        False
# 2          False        False        False             False        False
# 3          False        False        False             False        False
# 4          False        False        False             False        False
# ..           ...          ...          ...               ...          ...
# 88         False        False        False              True        False
# 89         False        False        False              True        False
# 90         False        False        False              True        False
# 91         False        False        False             False         True
# 92         False        False        False             False         True
#
# [93 rows x 58 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# 标准化
X = StandardScaler().fit_transform(X)
y = StandardScaler().fit_transform(y.reshape(-1, 1)).reshape(-1)

# 分割训练集与测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
